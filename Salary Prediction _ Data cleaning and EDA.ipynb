# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("glassdoor_data_raw.csv")

# %%
df
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 954         954                                      Data Engineer
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %%
df['hourly'] = df['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
df['employer_provided'] = df['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary:' in x.lower() else 0)

# %%
df = df[df['Salary Estimate'] != '-1']
salary = df['Salary Estimate'].apply(lambda x: x.split('(')[0])
minus_Kd = salary.apply(lambda x: x.replace('K','').replace('$',''))

# %%
minus_Kd
# Out:
# 0       53-91
# 1      63-112
# 2       80-90
# 3       56-97
# 4      86-143
#         ...
# 950    58-111
# 951    72-133
# 952     56-91
# 953    95-160
# 955    61-126
# Name: Salary Estimate, Length: 742, dtype: object

# %%
min_hr = minus_Kd.apply(lambda x: x.lower().replace('per hour','').replace('employer provided salary:',''))

# %%
df['min_salary'] = min_hr.apply(lambda x: int(x.split('-')[0]))
df['max_salary'] = min_hr.apply(lambda x: int(x.split('-')[1]))
# Out:
# C:\Users\Rose\AppData\Local\Temp\ipykernel_7644\3728426217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_salary'] = min_hr.apply(lambda x: int(x.split('-')[0]))
# C:\Users\Rose\AppData\Local\Temp\ipykernel_7644\3728426217.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_salary'] = min_hr.apply(lambda x: int(x.split('-')[1]))

# %%
df['avg_salary'] = (df.min_salary+df.max_salary)/2
# Out:
# C:\Users\Rose\AppData\Local\Temp\ipykernel_7644\1040917701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['avg_salary'] = (df.min_salary+df.max_salary)/2

# %%
df.head(5)
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# ...

# %%
#Company name text only.

# %%
df['company text']= df.apply(lambda x :x['Company Name'] if x['Rating'] < 0 else x['Company Name'][:-3], axis = 1)
# Out:
# C:\Users\Rose\AppData\Local\Temp\ipykernel_7644\963304294.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['company text']= df.apply(lambda x :x['Company Name'] if x['Rating'] < 0 else x['Company Name'][:-3], axis = 1)

# %%
df.drop(["company_text"], axis = 1, inplace = True)
# Out:
# C:\Users\Rose\AppData\Local\Temp\ipykernel_7644\4091535273.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(["company_text"], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# ...

# %%
df['company_text']= df.apply(lambda x :x['Company Name'] if x['Rating'] < 0 else x['Company Name'][:-3], axis = 1)
# Out:
# C:\Users\Rose\AppData\Local\Temp\ipykernel_7644\3494100909.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['company_text']= df.apply(lambda x :x['Company Name'] if x['Rating'] < 0 else x['Company Name'][:-3], axis = 1)

# %%
df.head(5)
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# ...

# %%
(df["Rating"] < 5).sum()
# Out:
# 737

# %%
df['state']=df['Location'].apply(lambda x:x.split(',')[1])
# Out:
# C:\Users\Rose\AppData\Local\Temp\ipykernel_7644\4046607791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['state']=df['Location'].apply(lambda x:x.split(',')[1])

# %%
df.head(5)
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# ...

# %%
df.state.value_counts()
# Out:
#  CA             151
#  MA             103
#  NY              72
#  VA              41
#  IL              40
#  MD              35
#  PA              33
#  TX              28
#  WA              21
#  NC              21
#  NJ              17
#  FL              16
#  OH              14
#  TN              13
#  DC              11
#  CO              11
#  WI              10
#  IN              10
#  UT              10
#  AZ               9
#  MO               9
#  AL               8
#  GA               6
#  KY               6
#  DE               6
#  MI               6
#  CT               5
#  IA               5
#  LA               4
#  OR               4
#  NE               4
#  NM               3
#  KS               3
#  ID               2
#  MN               2
#  Los Angeles      1
#  RI               1
#  SC               1
# Name: state, dtype: int64

# %%
df['same_state']=df.apply(lambda x: 1 if x.Location == x.Headquarters else 0, axis = 1)
# Out:
# C:\Users\Rose\AppData\Local\Temp\ipykernel_7644\569198718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['same_state']=df.apply(lambda x: 1 if x.Location == x.Headquarters else 0, axis = 1)

# %%
df.head(5)
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# ...

# %%
df['age'] = df.Founded.apply(lambda x : x if x < 1 else 2022 - x)
# Out:
# C:\Users\Rose\AppData\Local\Temp\ipykernel_7644\3987909933.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'] = df.Founded.apply(lambda x : x if x < 1 else 2022 - x)

# %%
df.head(5)
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# ...

# %%
#Parsing job description
#Python
df['python_yn'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
# Out:
# C:\Users\Rose\AppData\Local\Temp\ipykernel_7644\2962486689.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['python_yn'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)

# %%
#R studio
df['R_Studio'] = df['Job Description'].apply(lambda x: 1 if 'r studio' in x.lower() or 'r-studio' in x.lower() else 0)
# Out:
# C:\Users\Rose\AppData\Local\Temp\ipykernel_7644\665621851.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['R_Studio'] = df['Job Description'].apply(lambda x: 1 if 'r studio' in x.lower() or 'r-studio' in x.lower() else 0)

# %%
df.R_Studio.value_counts()
# Out:
# 0    740
# 1      2
# Name: R_Studio, dtype: int64

# %%
df['spark'] = df['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)
# Out:
# C:\Users\Rose\AppData\Local\Temp\ipykernel_7644\505723959.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spark'] = df['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)

# %%
df.spark.value_counts()
# Out:
# 0    575
# 1    167
# Name: spark, dtype: int64

# %%
df.drop(['sparx'], axis=1)
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 950         950           Sr Scientist, Immuno-Oncology - Oncology
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %%
df['aws'] = df['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)
# Out:
# C:\Users\Rose\AppData\Local\Temp\ipykernel_7644\3054027587.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['aws'] = df['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)

# %%
df['excel'] = df['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)
# Out:
# C:\Users\Rose\AppData\Local\Temp\ipykernel_7644\1582856640.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['excel'] = df['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)

# %%
df.head()
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# ...

# %%
df.drop(["Unnamed: 0"],axis=1)
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 950  $58K-$111K (Glassdoor est.)
# ...

# %%
df.to_csv("glassdoor_clean_data.csv", index = False)

# %%
df = pd.read_csv("glassdoor_clean_data.csv")

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'

    
def seniority (title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['job_simpl'] = df['Job Title'].apply(title_simplifier)

# %%
df
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 737         950           Sr Scientist, Immuno-Oncology - Oncology
# 738         951                               Senior Data Engineer
# 739         952  Project Scientist - Auton Lab, Robotics Institute
# 740         953                               Data Science Manager
# 741         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %%
df.job_simpl.value_counts()
# Out:
# data scientist    279
# na                184
# data engineer     119
# analyst           102
# manager            22
# mle                22
# director           14
# Name: job_simpl, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)

# %%
df.seniority.value_counts()
# Out:
# na        520
# senior    220
# jr          2
# Name: seniority, dtype: int64

# %%
df.state.value_counts()
df['state'] = df.state.apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')
df.state.value_counts()
# Out:
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# NC     21
# WA     21
# NJ     17
# FL     16
# OH     14
# TN     13
# DC     11
# CO     11
# WI     10
# UT     10
# IN     10
# AZ      9
# MO      9
# AL      8
# GA      6
# DE      6
# KY      6
# MI      6
# CT      5
# IA      5
# LA      4
# OR      4
# NE      4
# NM      3
# KS      3
# ID      2
# MN      2
# RI      1
# SC      1
# Name: state, dtype: int64

# %%
df['desc_len'] = df['Job Description'].apply(lambda x : len(x))

# %%
df['Competitors'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)

# %%
df['Competitors']
# Out:
# 0      0
# 1      0
# 2      0
# 3      3
# 4      3
#       ..
# 737    3
# 738    3
# 739    0
# 740    0
# 741    0
# Name: Competitors, Length: 742, dtype: int64

# %%
df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly == 1 else x.min_salary, axis = 1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly == 1 else x.max_salary, axis = 1)

# %%
df[df.hourly==1][['hourly','min_salary','max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 165       1          34          48
# 177       1          42          68
# 197       1          36          50
# 202       1          42          68
# 210       1          30          50
# 246       1          34          48
# 271       1          42          68
# 337       1          36          50
# 345       1          48          78
# 357       1          42          68
# 363       1          50          56
# 408       1          42          58
# 409       1          20          34
# 492       1          36          50
# 509       1          48          78
# 533       1          42          68
# 542       1          50          56
# 617       1          42          58
# 618       1          20          34
# 645       1          54          94
# 666       1          36          50
# 682       1          48          78
# 711       1          42          68
# 724       1          50          56

# %%
df['company_text'] = df['company_text'].apply(lambda x : x.replace('\n',''))

# %%
df['company_text']
# Out:
# 0                          Tecolote Research
# 1      University of Maryland Medical System
# 2                                    KnowBe4
# 3                                       PNNL
# 4                         Affinity Solutions
#                        ...
# 737                                      GSK
# 738                               Eventbrite
# 739           Software Engineering Institute
# 740                             Numeric, LLC
# 741             Riverside Research Institute
# Name: company_text, Length: 742, dtype: object

# %%
df.drop('Unnamed: 0', axis=1, inplace = True)

# %%
df.describe()
# Out:
#            Rating      Founded  Competitors      hourly  employer_provided  \
# count  742.000000   742.000000   742.000000  742.000000         742.000000
# mean     3.618868  1837.154987     1.053908    0.032345           0.022911
# std      0.801210   497.183763     1.384239    0.177034           0.149721
# min     -1.000000    -1.000000     0.000000    0.000000           0.000000
# 25%      3.300000  1939.000000     0.000000    0.000000           0.000000
# 50%      3.700000  1988.000000     0.000000    0.000000           0.000000
# 75%      4.000000  2007.000000     3.000000    0.000000           0.000000
# max      5.000000  2019.000000     4.000000    1.000000           1.000000
#
#        min_salary  max_salary  avg_salary  same_state         age   python_yn  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean    74.719677  128.149596  100.626011    0.557951   48.456873    0.528302
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'state', 'same_state', 'age', 'python_yn', 'R_Studio',
#        'sparx', 'spark', 'aws', 'excel', 'job_simpl', 'seniority', 'desc_len'],
#       dtype='object')

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.avg_salary.hist()
# Out:
# <AxesSubplot:>

# %%
df.age.hist()
# Out:
# <AxesSubplot:>

# %%
df.desc_len.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['age','avg_salary', 'Rating'])
# Out:
# <AxesSubplot:>

# %%
df[['age', 'avg_salary', 'Rating', 'desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000    0.019492  0.024665  0.164461
# avg_salary  0.019492    1.000000  0.013492  0.078808
# Rating      0.024665    0.013492  1.000000 -0.012281
# desc_len    0.164461    0.078808 -0.012281  1.000000

# %%
import seaborn as sns
cmap = sns.diverging_palette(220,10, as_cmap = True)
sns.heatmap(df[['age', 'avg_salary', 'Rating', 'desc_len','Competitors']].corr(),vmax=0.3, center = 0, cmap = cmap,square = True, linewidths = 0.5, cbar_kws={"shrink": 0.5})
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'state', 'same_state', 'age', 'python_yn', 'R_Studio',
#        'sparx', 'spark', 'aws', 'excel', 'job_simpl', 'seniority', 'desc_len'],
#       dtype='object')

# %%
df_cat = df[["Location","Headquarters",'Size', 'Type of ownership','Industry', 'Sector', 'Revenue','company_text', 'state','sparx', 'spark', 'aws', 'excel', 'job_simpl', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    sns.barplot(x=cat_num.index, y=cat_num)
    print("graph for %s: total = %d" % (i, len(cat_num)))
    plt.xticks(rotation = 90)
    plt.show()
# Out:
# graph for Location: total = 200
# graph for Headquarters: total = 198
# graph for Size: total = 9
# graph for Type of ownership: total = 11
# graph for Industry: total = 60
# graph for Sector: total = 25
# graph for Revenue: total = 14
# graph for company_text: total = 343
# graph for state: total = 37
# graph for sparx: total = 1
# graph for spark: total = 2
# graph for aws: total = 2
# graph for excel: total = 2
# graph for job_simpl: total = 7
# graph for seniority: total = 3

# %%
len(df['Location'])
# Out:
# 742

# %%
for i in df_cat[['Location','Headquarters','company_text']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    sns.barplot(x=cat_num.index, y=cat_num)
    print("graph for %s: total = %d" % (i, len(cat_num)))
    plt.xticks(rotation = 90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for company_text: total = 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'state', 'same_state', 'age', 'python_yn', 'R_Studio',
#        'sparx', 'spark', 'aws', 'excel', 'job_simpl', 'seniority', 'desc_len'],
#       dtype='object')

# %%
pd.pivot_table(df,index = 'job_simpl', values = 'avg_salary')
# Out:
#                 avg_salary
# job_simpl
# analyst          65.857843
# data engineer   105.403361
# data scientist  117.564516
# director        168.607143
# manager          84.022727
# mle             126.431818
# na               84.853261

# %%
pd.pivot_table(df,index = ['job_simpl','seniority'], values = 'avg_salary')
# Out:
#                           avg_salary
# job_simpl      seniority
# analyst        jr          56.500000
#                na          61.155405
#                senior      79.092593
# data engineer  na          96.701220
#                senior     124.689189
# data scientist jr         106.500000
#                na         107.043011
#                senior     138.956522
# director       na         168.607143
# manager        na          84.022727
# mle            na         119.133333
#                senior     142.071429
# na             na          73.988189
#                senior     109.061404

# %%
pd.pivot_table(df,index = 'state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#        avg_salary
# state
# CA     123.513158
# IL     116.662500
# DC     110.181818
# MA     106.281553
# NJ     104.558824
# MI     100.250000
# RI     100.000000
# NY      98.652778
# NC      98.452381
# MD      97.357143
# KY      97.000000
# VA      95.621951
# UT      94.150000
# WA      93.190476
# PA      92.560606
# OR      92.125000
# IN      90.300000
# TX      89.392857
# OH      87.571429
# TN      87.115385
# KS      87.000000
# AZ      85.666667
# MN      85.500000
# MO      84.722222
# GA      80.666667
# IA      78.900000
# FL      77.625000
# CO      77.045455
# NM      74.333333
# WI      73.300000
# CT      71.100000
# SC      60.500000
# AL      57.937500
# ID      56.250000
# LA      52.250000
# NE      41.000000
# DE      27.500000

# %%
pd.pivot_table(df,index = ['state','job_simpl'], values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#                       avg_salary
# state job_simpl
# IL    director        221.750000
# CA    mle             177.300000
# NJ    director        161.500000
# DC    data scientist  149.000000
# CA    data scientist  142.522059
# ...                          ...
# CO    na               31.500000
#       analyst          29.500000
# DE    na               27.500000
# LA    na               20.000000
# TN    analyst          13.500000
#
# [114 rows x 1 columns]

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.set_option('display.max_rows',None)

# %%
pd.pivot_table(df,index = ['state','job_simpl'], values = 'avg_salary').sort_values('state', ascending = False)
# Out:
#                       avg_salary
# state job_simpl
# WI    na               54.000000
#       data scientist  113.500000
#       analyst          58.833333
# WA    na               97.500000
#       data scientist   99.764706
#       analyst          54.500000
# VA    na               79.300000
#       mle              87.000000
#       data scientist  108.416667
#       data engineer    96.900000
#       analyst          71.583333
# UT    data engineer   100.333333
#       analyst          54.750000
#       data scientist  140.500000
# TX    na               41.285714
#       data scientist  100.730769
#       data engineer   113.062500
# TN    data scientist   96.000000
#       data engineer   100.950000
#       analyst          13.500000
# SC    na               60.500000
# RI    analyst         100.000000
# PA    manager         109.666667
#       data engineer    91.500000
#       data scientist  113.333333
#       analyst          62.750000
#       mle             120.500000
# ...

# %%
pd.pivot_table(df[df.job_simpl == 'data scientist'], index = 'state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#        avg_salary
# state
# DC     149.000000
# CA     142.522059
# UT     140.500000
# MO     127.666667
# IL     117.233333
# NC     117.000000
# NY     115.250000
# MA     113.750000
# WI     113.500000
# PA     113.333333
# MD     109.115385
# CO     108.666667
# VA     108.416667
# NJ     106.875000
# MI     106.625000
# OH     105.285714
# TX     100.730769
# WA      99.764706
# OR      98.500000
# FL      97.357143
# TN      96.000000
# IN      84.500000
# KY      84.000000
# CT      84.000000
# GA      81.333333
# NM      74.333333
# AZ      69.500000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'state', 'same_state', 'age', 'python_yn', 'R_Studio',
#        'sparx', 'spark', 'aws', 'excel', 'job_simpl', 'seniority', 'desc_len'],
#       dtype='object')

# %%
df_pivots=df[['Rating','Industry', 'Sector', 'Revenue','Competitors',
       'hourly', 'employer_provided','python_yn', 'R_Studio',
       'sparx', 'spark', 'aws', 'excel','Type of ownership','avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots,index=i, values = 'avg_salary').sort_values( 'avg_salary')
# Out:
#   Input In [52]
#     print(pd.pivot_table(df_pivots,index=i, values = 'avg_salary').sort_values( 'avg_salary')
#                                                                                              ^
# SyntaxError: unexpected EOF while parsing

# %%
df.head(5)
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
df.to_csv("glassdoor_clean_data_eda.csv", index = False)
